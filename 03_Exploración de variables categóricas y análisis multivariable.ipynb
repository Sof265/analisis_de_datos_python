# %% [markdown]
# # **03. Exploración de variables categóricas y análisis multivariable.**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('white')

# %%
df= pd.read_csv('/content/drive/MyDrive/BEDU/analisis_datos_python_2021/COVID-19 Survey Student Responses-clean.csv', index_col=0)
df.head(3)
# Out:
#                      Age of Subject  ...  What you miss the most
# Region of residence                  ...
# Delhi-NCR                        21  ...          School/college
# Delhi-NCR                        21  ...   Roaming around freely
# Delhi-NCR                        20  ...              Travelling
#
# [3 rows x 17 columns]

# %% [markdown]
# ## Identificamos las variables categóricas

# %%
df_cat = df.select_dtypes('object')
df_cat.head(3)
# Out:
#                     Rating of Online Class experience  ... What you miss the most
# Region of residence                                    ...
# Delhi-NCR                                        Good  ...         School/college
# Delhi-NCR                                   Excellent  ...  Roaming around freely
# Delhi-NCR                                   Very poor  ...             Travelling
#
# [3 rows x 9 columns]

# %% [markdown]
# Ahora exploramos la distribución de las variables

# %%
counts = df['Rating of Online Class experience'].value_counts()
ax = sns.barplot(x=counts.index, y=counts, order=counts.index)
ax.set_title('Rating')
ax.set(ylabel='Frecuencia');

# %%
counts = df['Medium for online class'].value_counts()
ax = sns.barplot(x=counts.index, y=counts, order=counts.index)
ax.set_title('Dispositivo')
ax.set(ylabel='Frecuencia');
ax.set_xticklabels(ax.get_xticklabels(), rotation=20);

# %%
counts = df['Prefered social media platform'].value_counts()
ax = sns.barplot(x=counts.index, y=counts, order=counts.index)
ax.set_title('Plataforma')
ax.set(ylabel='Frecuencia');
ax.set_xticklabels(ax.get_xticklabels(), rotation=50);

# %%
counts = df['Change in your weight'].value_counts()
ax = sns.barplot(x=counts.index, y=counts, order=counts.index)
ax.set_title('Cambios en el peso')
ax.set(ylabel='Frecuencia');

# %%
counts = df['Health issue during lockdown'].value_counts()
ax = sns.barplot(x=counts.index, y=counts, order=counts.index)
ax.set_title('Problemas de salud durante el encierro')
ax.set(ylabel='Frecuencia');
